# %%
import json

file_api_path = '/lakehouse/default/Files/pipeline_information/'
file_name = 'first_run.json'

with open(file_api_path + file_name, 'r') as file:
    data = json.load(file)

data['first_run'] = 0

with open(file_api_path + file_name, 'w') as file:
    json.dump(data, file, indent=4)

print('first_run avaimen arvo muutettu 0:ksi.')
# Out:
# StatementMeta(, 9d0cde23-8d39-4171-8458-597c6381d0a4, 3, Finished, Available, Finished)
# first_run avaimen arvo muutettu 0:ksi.
